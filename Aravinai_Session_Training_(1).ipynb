# %% [markdown]
# <a href="https://colab.research.google.com/github/Rithika773/Python-Classes-and-objects/blob/main/Aravinai_Session_Training_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\dk9\Downloads\Finance_data.csv')

# %%
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
df.groupby(['PPF'])['PPF'].count()
# Out:
# PPF
# 1    24
# 2     6
# 3     3
# 4     2
# 5     2
# 6     3
# Name: PPF, dtype: int64

# %%
df['age'].describe()
# Out:
# count    40.000000
# mean     27.800000
# std       3.560467
# min      21.000000
# 25%      25.750000
# 50%      27.000000
# 75%      30.000000
# max      35.000000
# Name: age, dtype: float64

# %%
np.where(df['PPF']>2)
# Out:
# (array([ 0,  1,  3,  4, 12, 28, 30, 32, 33, 36], dtype=int64),)

# %%
df2=df[( (df['PPF']>=1) & (df['PPF']<=3) ) ]

# %%
min 25 50 75 max mean

# %%
df2['age'].quantile([0.01,0.1,0.9,0.99])
# Out:
# 0.01    21.96
# 0.10    25.00
# 0.90    31.80
# 0.99    35.00
# Name: age, dtype: float64

# %%
np.mean(df['PPF'])
# Out:
# 2.025

# %%
df['PPF'].quantile

# %%
df['PPF'].value_counts()
# Out:
# 1    24
# 2     6
# 3     3
# 6     3
# 4     2
# 5     2
# Name: PPF, dtype: int64

# %%
sns.countplot(df['PPF'])
# Out:
# C:\Users\dk9\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['Mutual_Funds'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c0b42a5d08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c0b42acbc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c0b42a5b48>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c0b42b0b48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c0b42b5a08>],
#  'means': []}

# %%
sns.boxplot(df['age'])
# Out:
# C:\Users\dk9\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
IQR = 75 - 25
(min-1.5*IQR)  (max+1.5*IQR)

# %%
len(df)
# Out:
# 40

# %%
df.shape
# Out:
# (40, 24)

# %%
Sun 40C
Mon 40C
Tue 40C
Wed 2C
Thur 40C
Fri 40C
Sat 40C

# %%
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
data=pd.DataFrame(df.groupby(['gender'])['Mutual_Funds'].sum()).reset_index()

# %%
for row,each in data.iterrows():
    print(each)
# Out:
# gender          Female
# Mutual_Funds        41
# Name: 0, dtype: object
# gender          Male
# Mutual_Funds      61
# Name: 1, dtype: object

# %%
data.loc[0]
# Out:
# gender          Female
# Mutual_Funds        41
# Name: 0, dtype: object

# %%
data.loc[0]['Mutual_Funds']
# Out:
# 41

# %%
df[['gender','Mutual_Funds']]
# Out:
#     gender  Mutual_Funds
# 0   Female             1
# 1   Female             4
# 2     Male             3
# 3     Male             2
# 4   Female             2
# 5   Female             7
# 6   Female             3
# 7     Male             2
# 8     Male             2
# 9     Male             1
# 10  Female             2
# 11    Male             2
# 12  Female             1
# 13  Female             2
# 14  Female             2
# 15    Male             2
# 16  Female             3
# 17    Male             3
# 18    Male             3
# 19    Male             3
# 20    Male             2
# 21  Female             2
# 22    Male             3
# 23    Male             2
# 24  Female             2
# 25  Female             3
# 26    Male             3
# 27    Male             2
# 28    Male             2
# 29  Female             5
# 30    Male             4
# 31  Female             2
# 32    Male             2
# 33    Male             2
# 34    Male             2
# 35    Male             1
# ...

# %%
sns.barplot(data['gender'],data['Mutual_Funds'])
# Out:
# C:\Users\dk9\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
data1=pd.DataFrame(df.groupby(['age','Source'])['age'].count()).rename(columns={'age':'Count_Of_people'}).reset_index()

# %%
data1
# Out:
#     age                    Source  Count_Of_people
# 0    21                  Internet                1
# 1    21  Newspapers and Magazines                1
# 2    22                  Internet                1
# 3    23     Financial Consultants                1
# 4    24                  Internet                2
# 5    24  Newspapers and Magazines                1
# 6    25     Financial Consultants                3
# 7    26     Financial Consultants                1
# 8    26  Newspapers and Magazines                3
# 9    27     Financial Consultants                4
# 10   27  Newspapers and Magazines                2
# 11   27                Television                1
# 12   28  Newspapers and Magazines                1
# 13   28                Television                1
# 14   29     Financial Consultants                3
# 15   29  Newspapers and Magazines                1
# 16   29                Television                1
# ...

# %%
sns.barplot(x=data1['age'],y=data1['Count_Of_people'],hue=data1['Source'])

# %%
df.corr()
# Out:
#                        age  Mutual_Funds  Equity_Market  Debentures  \
# age               1.000000     -0.123914       0.246840    0.326638
# Mutual_Funds     -0.123914      1.000000       0.332043   -0.351495
# Equity_Market     0.246840      0.332043       1.000000   -0.016898
# Debentures        0.326638     -0.351495      -0.016898    1.000000
# Government_Bonds -0.093632     -0.114198      -0.237420    0.430323
# Fixed_Deposits   -0.033685     -0.031604      -0.238705   -0.470791
# PPF              -0.263167     -0.193665      -0.429003   -0.511169
# Gold             -0.057952     -0.401830      -0.050027   -0.137195
#
#                   Government_Bonds  Fixed_Deposits       PPF      Gold
# age                      -0.093632       -0.033685 -0.263167 -0.057952
# Mutual_Funds             -0.114198       -0.031604 -0.193665 -0.401830
# Equity_Market            -0.237420       -0.238705 -0.429003 -0.050027
# Debentures                0.430323       -0.470791 -0.511169 -0.137195
# ...

# %%
target= Gold

# %%
-1 to 1

# %%
sns.lineplot(df['Fixed_Deposits'],df['Government_Bonds'])
# Out:
# C:\Users\dk9\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[['Fixed_Deposits','Government_Bonds']]
# Out:
#     Debentures  Government_Bonds
# 0            5                 3
# 1            2                 1
# 2            4                 2
# 3            3                 7
# 4            3                 6
# 5            4                 6
# 6            4                 2
# 7            7                 4
# 8            7                 5
# 9            7                 4
# 10           7                 5
# 11           7                 6
# 12           3                 4
# 13           7                 4
# 14           7                 5
# 15           7                 5
# 16           7                 5
# 17           7                 4
# 18           7                 4
# 19           6                 5
# 20           7                 5
# 21           5                 6
# 22           6                 5
# 23           6                 5
# 24           7                 5
# 25           7                 5
# 26           6                 5
# ...

# %%
sns.displot(df['age'])

# %%
sns.countplot(df['age'])
# Out:
# C:\Users\dk9\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Investment_Avenues'].value_counts()
# Out:
# Yes    37
# No      3
# Name: Investment_Avenues, dtype: int64

# %%
df.loc[df['Investment_Avenues']=='Yes','Investment_Avenues_c']=1
df.loc[df['Investment_Avenues']=='No','Investment_Avenues_c']=0

# %%
pd.get_dummies(df['Investment_Avenues'])
# Out:
#     No  Yes
# 0    0    1
# 1    0    1
# 2    0    1
# 3    0    1
# 4    1    0
# 5    1    0
# 6    0    1
# 7    0    1
# 8    0    1
# 9    0    1
# 10   0    1
# 11   0    1
# 12   1    0
# 13   0    1
# 14   0    1
# 15   0    1
# 16   0    1
# 17   0    1
# 18   0    1
# 19   0    1
# 20   0    1
# 21   0    1
# 22   0    1
# 23   0    1
# 24   0    1
# 25   0    1
# 26   0    1
# 27   0    1
# 28   0    1
# 29   0    1
# 30   0    1
# 31   0    1
# 32   0    1
# 33   0    1
# 34   0    1
# 35   0    1
# 36   0    1
# 37   0    1
# 38   0    1
# 39   0    1

# %%
df[['Investment_Avenues','Investment_Avenues_c']]
# Out:
#    Investment_Avenues  Investment_Avenues_c
# 0                 Yes                   1.0
# 1                 Yes                   1.0
# 2                 Yes                   1.0
# 3                 Yes                   1.0
# 4                  No                   0.0
# 5                  No                   0.0
# 6                 Yes                   1.0
# 7                 Yes                   1.0
# 8                 Yes                   1.0
# 9                 Yes                   1.0
# 10                Yes                   1.0
# 11                Yes                   1.0
# 12                 No                   0.0
# 13                Yes                   1.0
# 14                Yes                   1.0
# 15                Yes                   1.0
# 16                Yes                   1.0
# 17                Yes                   1.0
# 18                Yes                   1.0
# 19                Yes                   1.0
# ...

# %%
df['Invest_Monitor'].value_counts()
# Out:
# Monthly    29
# Weekly      7
# Daily       4
# Name: Invest_Monitor, dtype: int64

# %%
* Reading external csv file
* len,shape of data
* descriptive stats
* IQR box plot quantiles
* correlation
* group by (detail), multi level grouping
* condition based slicing the data (and,or)
* reset index()
* Handling categorical values
* seaborn sns plots
